# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
a, b = map(float,input().split())
chu_vi= (a+b)*2
dien_tich= a*b
print(f"{chu_vi}, {dien_tich}")
# Out:
# 18.0, 20.0

# %%
def chu_vi(a,b):
    return(a+b)*2
def dien_tich(a,b):
    return a*b
a,b = map(float,input().split())
print(chu_vi(a,b))
print(dien_tich(a,b))
# Out:
# 14.0
# 12.0

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r= float(input())
dien_tich = 3.14 * r*r
chu_vi= 3.14 * ( r*2)
print(chu_vi,dien_tich)
# Out:
# 25.12 50.24

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là độ dài ba cạnh hay không, nếu  không thì in  ra màn  hình  'Khong la ba  canh cua mot tam  giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn
# hình.

# %%
import math
a,b,c = map(int,input().split())
if a<=0 or b<=0 or c<=0:
    print("khong thoa man")
elif (a+c>b) and (a+b>c) and (b+c>a):
    p = (a+b+c)/2
    dien_tich = math.sqrt(p*(p-a)*(p-b)*(p-c))
    chu_vi= a+b+c
    print(f"{chu_vi},{dien_tich}")
    if (a==b==c):
        print("Tam giac deu")
    elif (a==b!=c) or (a==c!=b) or (b==c!=a):
        print("tam giac can")
    elif (a**22 + b**2 == c**2) or (b**2 + a**2== c**2) or (c**2 + b**2== a**2):
        print("tam giac vuong")
    else:
        print("tam giac thuong")
else:
    print("khong la ba canh cua mot tam giac")
# Out:
# khong thoa man

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b = map(int,input().split())
x = - b / a
print(f"Phuong trinh bac 1 a*x +b =0 la {x}")
# Out:
# Phuong trinh bac 1 a*x +b =0 la -1.25

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c = map(int,input().split())
delta = b**2 - 4*a*c
if delta>0:
    x1 = ((-b + delta**0.5) 2*a)
    x2=  ((-b - delts**0.5)/2*a)
    print(f"{x1}, {x2}")
elif delta ==0 :
    x= -b/2*a
    print(f"{x}")
else:
    print("Phuong trinh vo nghiem")
# Out:
# Phuong trinh vo nghiem

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d = map(float, input().split())
big = max (a,b,c,d)
print(f"{big}")
# Out:
# 6.0

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d = map(float, input().split())
small = min(a,b,c,d)
print(f"{small}")
# Out:
# 2.0

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax + by = m
# cx + dy = n

# %%
a,b,c,d,m,n = map(int,input().split())
y = (n*a-c*m)/(a*d-c*b)
x = (m-b*y)/a
print(f"{x},{y}")
# Out:
# -4.0,4.5

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao
# nhiêu giây.

# %%
x = int(input())
gio = x//3600
phut = ((x%3600)/3600)*60
print(f"{gio} giờ {phut} phút")
# Out:
# 1 giờ 30.0 phút

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
x,y,a,b,r = map(int,input().split())
phuong_trinh_duong_tron = (x-a)**2 + (y-b)**2 <= r**2
print(f"{phuong_trinh_duong_tron}")
# Out:
# True

# %% [markdown]
# Bài 11: Tính x**y (Với x, y là số thực).

# %%
x,y = map(int,input().split())
s = x**y
print(f"{s}")
# Out:
# 1024

# %% [markdown]
# Bài tập tuần 3

# %% [markdown]
# Bài 1:Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau.

# %%
n = input()
print(n[::-1])
# Out:
# 5432

# %%
n= int(input())
while n >0:
    chu_so_cuoi = n%10
    print(chu_so_cuoi, end="") # end="" ép python ko được xuống dòng
    n = n//10
# Out:
# 4321

# %% [markdown]
# Bài 2:Hoán đổi hai số không sd biến tạm thời Sử dụng phép toán XOR bitwise để hoán đổi giá trị của hai biến.

# %%
a,b= map(int,input().split())
a = a^b # a^a =0 , x^0 =x, a^b == b^a
b = a^b
a = a^b
print(a,b)
# Out:
# 4321 1234

# %% [markdown]
# Bài 3: Kiểm tra xem một số có phải là lũy thừa của 2 hay không Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không.

# %%
n = int(input())
kiem_tra = (n>0) and (n & (n-1)==0)
print(kiem_tra)
# Out:
# False

# %% [markdown]
# Bài 4:Viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
m,n = map(int,input().split())
chia = m // n
print(chia)
# Out:
# 5

# %% [markdown]
# Bài 5:Viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
m,n = map(int, input().split())
chia = (m//n) + 1
print(chia)
# Out:
# -2

# %% [markdown]
# Bài 6:Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".

# %%
x = int(input())
if x%2 == 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %% [markdown]
# Bài 7:Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a,b = map(int, input().split())
if a <0 and b< 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# Bài 8:Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False".

# %%
a,b = input().split()
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# Bài 9:Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không. Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a,b,c = map(int, input().split())
if a+b>c and a+c>b and b+c>a:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# Bài 10:Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a,b,c,d = map(int, input().split())
lon = max(a,b,c,d)
print(lon)
# Out:
# 6

# %% [markdown]
# Bài 11: Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay "Tam giác thường".

# %%
a,b,c = map(int, input().split())
if a<= 0 or b <= 0 or c<= 0:
    print("khong thoa man")
elif a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("tam giac deu")
    elif a==b!=c or a==c!=b or b==c!=a:
        print("tam giac can")
    elif (a**2+b**2==c**2) or (a**2+c**2==b**2) or (b**2+c**2==a**2):
        print("tam giac vuong")
    else:
        print("tam giac thuong")
else:
    print("khong la tam giac")
# Out:
# tam giac deu

# %% [markdown]
# Bài 12:Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
n = int(input())
if (n%4==0 and n%100!=0) or (n%400==0):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# Bài 13: Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau: - 0-50 kWh: 1500đ/kWh - 51-100 kWh: 2000đ/kWh - 100 kWh: 3000đ/kWh

# %%
x = int(input())
if 0 <= x <=50:
    tien = x*1500
    print(tien)
elif 51<= x <= 100:
    h= 50*1500 + (x-50)*2000
    print(h)
elif x>100:
    s=50*1500 + 50*2000 + (x-100)*3000
    print(s)
else:
    print("khong thoa man")
# Out:
# khong thoa man

# %% [markdown]
# Bài 14:Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a,b= map(float, input().split())
if a==0 and b==0:
    print("Vô số nghiệm")
elif (a==0 and b!=0) or (b==0 and a!=0):
    print("Vô nghiệm")
else:
    x= -b/a
    print(f"{x:.2f}")
# Out:
# -430.87

# %% [markdown]
# Bài 15:Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc: - >= 8.0: Giỏi - >= 6.5: Khá - >= 5.0: Trung bình - < 5.0: Yếu

# %%
n = float(input())
if n<0:
    print("khong thoa man")
elif 10>= n >= 8.0:
    print("Giỏi")
elif 8.0>= n>= 6.5:
    print("Khá")
elif 6.5>= n >= 5.0:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Yếu

# %% [markdown]
# Bài 16:Nhập vào một số thực: in ra kết quả làm tròn lên ,tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm sẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
n = float(input())
phan_nguyen = int(n)
if n== phan_nguyen:
    len = phan_nguyen
elif n>0:
    len = phan_nguyen+1
else:
    len = phan_nguyen

if n== phan_nguyen:
    xuong = phan_nguyen
elif n>0:
    xuong = phan_nguyen
else:
    xuong = phan_nguyen -1

if n>=0:
    gan = int(n+0.5)
else:
    gan = int(n-0.5)
print(len , xuong , gan)
# Out:
# -5 -6 -6

# %% [markdown]
# Bài 17:Cấp số nhân
# Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng thứ tự a, b, c, d hay không?
# Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs
# d.

# %%
a,b,c,d = map(int, input().split())
if b/a == c/b == d/c:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# LT: thời gian

# %%
import datetime
today = datetime.datetime.today()
print(f"{today:%B %d %Y}")
# Out:
# March 12 2026

# %% [markdown]
# Lấy 2 chữ số phần thập phân

# %%
x = 28.3456
y = 34.6789
print(f"Số thứ nhất: {x:.2f} Số thứ hai: {y:.2f}")
# Out:
# Số thứ nhất: 28.35 Số thứ hai: 34.68

# %% [markdown]
# In 2 số chung 1 dòng

# %%
x , y = map(int,input().split())
print(x,y)
# Out:
# 4 6

# %% [markdown]
# Bài tập

# %% [markdown]
# Bài 3:Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập phân) theo định dạng đúng của output

# %%
a,b = map(int,input().split())
tong= a + b
hieu=a-b
phan_nguyen= a//b
phan_du= a%b
chia= a/b
print(tong)
print(hieu)
print(phan_nguyen)
print(phan_du)
print(f"{chia:.2f}")
# Out:
# 15
# 1
# 1
# 1
# 1.14

# %% [markdown]
# Bài 6:Hãy nhập vào một kí tự chữ cái thường ‘a’…’z’, in ra mã Unicode của nó sau đó chuyển nó thành kí
# tự hoa tương ứng, in kí tự hoa này ra màn hình.

# %%
n = input("Nhập chữ cái thường: ")
ki_tu_hoa= n.upper()
print(f"{ki_tu_hoa}")
# Out:
# D

# %%
n = input("Nhập chữ cái thường: ")
ki_tu_hoa=chr(ord(n)-32)
print(f"{ki_tu_hoa}")
# Out:
# D

# %% [markdown]
# Bài 7:Hãy in ra kết quả của hai biểu thức sau:
# A = ((13 ** 2) * 3) + 5 và B = 13**2*3 + 5

# %%
A = ((13**2)*3)+5
B= 13**2*3 +5
print(A)
print(B)
# Out:
# 512
# 512

# %% [markdown]
# Bài 9:Sơn Tùng mua một chiếc đồng hồ Movado trên trang mua sắm trực tuyến Amazon. Chiếc đồng hồ có giá x USD (x nhập từ bàn phím). Bởi Amazon không vận chuyển trực tiếp về Việt Nam, Đạt phải trả 10 USD cho phí vận chuyển từ một nước trung gian. Khi vận chuyển về Việt Nam, Đạt được thông báo sẽ phải trả thêm 30% thuế xuất nhập cảnh và 10% thuế VAT cho chiếc đồng hồ nói trên. Viết chương trình tính tổng số tiền mà Đạt phải trả để mua
# được chiếc đồng hồ trên (USD). Kết quả làm tròn đến hai chữ số thập phân.

# %%
x = float(input("Giá của đồng hồ: "))
A = (x*1.4+10)
print(f"{A:.2f}")
# Out:
# 20.36

# %% [markdown]
# Bài 10:Viết chương trình nhập vào tên 3 người từ bàn phím. In ra màn hình tên theo thứ tự đảo ngược.
# VD: input ("Bob Alice Helen") thì output: ("Hi Helen, Alice and Bob.")

# %%
a,b,c= map(str,input("Tên: ").split())
print(f"Hi {c},{b} and {a}")
# Out:
# Hi C,B and A

# %% [markdown]
# Bài 11:Viết chương trình chuyển từ giờ và phút sang giây
# Đầu vào gồm hai giá trị chứa số giờ \h và số phút \m:
# Đầu ra: In ra màn hình một dòng duy nhất số giờ và phút được chuyển sang đơn vị giây.

# %%
a , b= map(int,input().split())
A = a * 3600 + b*60
print (f"{A}")
# Out:
# 11280

# %% [markdown]
# Bài 12:Cho một khối Rubik có độ dài cạnh là n, hãy trả về số lượng miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương. Ví dụ, khối rubic có độ dài cạnh là 1 cần 6 miếng dán riêng lẻ. (Lưu ý: một khối rubic có 6 mặt)

# %%
n = int(input())
A= 6 * ( n**2)
print(A)
# Out:
# 36

# %% [markdown]
# Bài 13:Nhập vào từ bàn phím hai số nguyên dương \a và \b, viết chương trình trả về hàng đơn vị của phép tính tích giữa \a và \b.

# %%
a ,b = map(int,input().split())
n= ( a* b)%10
print(n)
# Out:
# 2

# %% [markdown]
# Bài 13:Viết chương trình hoán đổi giá trị giữa hai số a và b mà không cần khai báo thêm một biến/ hàm nào khác.

# %%
a,b = map(int, input().split())
a,b= b,a
print(a,b )
# Out:
# 7 5

# %% [markdown]
# khi gặp dấu ‘\n’ là một kí tự xuống dòng được in ra.

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
print("January\nfebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# february
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# Bài 21:Viết chương trình in ra màn hình dòng chữ "Hello, world" 10 lần.

# %%
print("Hello, world\n"*10)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
